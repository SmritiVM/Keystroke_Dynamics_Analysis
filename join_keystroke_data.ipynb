# %%
import pandas as pd
import glob
# Out:
# C:\Users\skhim\AppData\Local\Temp\ipykernel_14368\329695546.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df_csv_concat = pd.concat([pd.read_csv(file) for file in glob.glob('*_bks.csv')], ignore_index=True)
df_csv_concat
# Out:
#       name  rep  H.period       H.t  DD.period.t  UD.period.t       H.i  \
# 0  smriti2    1  0.070398  0.060515     0.812225     0.872740  0.063264
# 1  smriti2    2  0.053514  0.079391     0.282900     0.362292  0.073059
# 2   smriti    1  0.072375  0.064863     0.281705     0.346568  0.057331
# 3   smriti    2  0.053421  0.088685     0.278894     0.367578  0.060085
#
#      DD.t.i    UD.t.i       H.e  ...       H.n    DD.o.n    UD.o.n       H.a  \
# 0  0.157202  0.220465  0.056946  ...  0.045079  0.238739  0.283818  0.103169
# 1  0.157754  0.230813  0.094397  ...  0.060627  0.233029  0.293656  0.123686
# 2  0.157712  0.215043  0.080267  ...  0.068741  0.239686  0.308428  0.123890
# 3  0.176866  0.236951  0.094953  ...  0.065851  0.182974  0.248826  0.097838
#
#      DD.n.a    UD.n.a       H.l    DD.a.l    UD.a.l  backspaces
# 0  0.173727  0.276896  0.053481  0.122870  0.176351           0
# 1  0.124037  0.247723  0.055238  0.126913  0.182151           0
# ...
